# %%
import pandas as pd

# %% [markdown]
# ## Series Data Structures

# %%
ser = pd.Series([100, 'foo', 300, 'bar'], ['scott', 'bob', 'joe', 'steve'])

# %%
print(ser)
# Out:
# scott    100
# bob      foo
# joe      300
# steve    bar
# dtype: object

# %%
ser.index
# Out:
# Index(['scott', 'bob', 'joe', 'steve'], dtype='object')

# %%
ser['bob']
# Out:
# 'foo'

# %%
ser.loc['joe']
# Out:
# 300

# %%
ser[['scott','bob']]
# Out:
# scott    100
# bob      foo
# dtype: object

# %%
ser[[3, 2, 1]]
# Out:
# steve    bar
# joe      300
# bob      foo
# dtype: object

# %%
ser.iloc[2]
# Out:
# 300

# %%
'scott' in ser
# Out:
# True

# %%
'nancy' in ser
# Out:
# False

# %%
ser * 2
# Out:
# scott       200
# bob      foofoo
# joe         600
# steve    barbar
# dtype: object

# %%
ser * 4
# Out:
# scott             400
# bob      foofoofoofoo
# joe              1200
# steve    barbarbarbar
# dtype: object

# %%
ser * 2
# Out:
# scott       200
# bob      foofoo
# joe         600
# steve    barbar
# dtype: object

# %%
ser[['scott', 'joe']] ** 2
# Out:
# scott    10000
# joe      90000
# dtype: object

# %% [markdown]
# ## Pandas Dataframes

# %%
#create dataframe out of series of data objects
d = {'one': pd.Series([100, 200, 300], index=['apple', 'ball', 'clock']),
     'two': pd.Series([111,222,333,4444],index=['apple', 'ball', 'something', 'another'])}

# %%
db = pd.DataFrame(d)

# %%
pd.DataFrame(d, index=['apple', 'ball', 'clock'])
# Out:
#        one    two
# apple  100  111.0
# ball   200  222.0
# clock  300    NaN

# %%
#create dataframe out of series of data objects
da = {'one': pd.Series([100, 200, 300], index=['A1', 'A2', 'A3']),
     'two': pd.Series([111,222,333,4444],index=['A1', 'A2', 'A3', 'A4'])}

# %%
df = pd.DataFrame(da)

# %%
print(df)
# Out:
#       one   two
# A1  100.0   111
# A2  200.0   222
# A3  300.0   333
# A4    NaN  4444

# %%
df.index
# Out:
# Index(['A1', 'A2', 'A3', 'A4'], dtype='object')

# %%
df.columns
# Out:
# Index(['one', 'two'], dtype='object')

# %%
df.one
# Out:
# A1    100.0
# A2    200.0
# A3    300.0
# A4      NaN
# Name: one, dtype: float64

# %%
df
# Out:
#       one   two
# A1  100.0   111
# A2  200.0   222
# A3  300.0   333
# A4    NaN  4444

# %%
df['one']
# Out:
# A1    100.0
# A2    200.0
# A3    300.0
# A4      NaN
# Name: one, dtype: float64

# %%
df['three'] = df['one'] * df['two']

# %%
df
# Out:
#       one   two    three
# A1  100.0   111  11100.0
# A2  200.0   222  44400.0
# A3  300.0   333  99900.0
# A4    NaN  4444      NaN

# %%
df['flag'] = df['one']>250

# %%
df
# Out:
#       one   two    three   flag
# A1  100.0   111  11100.0  False
# A2  200.0   222  44400.0  False
# A3  300.0   333  99900.0   True
# A4    NaN  4444      NaN  False

# %%
#remove or delete data from data fram
#df pop return column with i
three
# Out:
# A1    11100.0
# A2    44400.0
# A3    99900.0
# A4        NaN
# Name: three, dtype: float64

# %%
df
# Out:
#       one   two   flag
# A1  100.0   111  False
# A2  200.0   222  False
# A3  300.0   333   True
# A4    NaN  4444  False

# %%
df['three'] = three

# %%
df
# Out:
#       one   two   flag    three
# A1  100.0   111  False  11100.0
# A2  200.0   222  False  44400.0
# A3  300.0   333   True  99900.0
# A4    NaN  4444  False      NaN

# %%
df
# Out:
#       one   two   flag    three
# A1  100.0   111  False  11100.0
# A2  200.0   222  False  44400.0
# A3  300.0   333   True  99900.0
# A4    NaN  4444  False      NaN

# %%
df.insert(1, 'copy_of_onsex', df['one'])

# %%
df
# Out:
#       one  copy_of_onsex   two  copy_of_one   flag  copy_of_onex    three
# A1  100.0          100.0   111        100.0  False         100.0  11100.0
# A2  200.0          200.0   222        200.0  False         200.0  44400.0
# A3  300.0          300.0   333        300.0   True         300.0  99900.0
# A4    NaN            NaN  4444          NaN  False           NaN      NaN

# %%
df.columns
# Out:
# Index(['one', 'copy_of_onsex', 'two', 'copy_of_one', 'flag', 'copy_of_onex',
#        'three'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 8

# %%
df
# Out:
#       one  copy_of_onsex   two  copy_of_one   flag  copy_of_onex    three  \
# A1  100.0          100.0   111        100.0  False         100.0  11100.0
# A2  200.0          200.0   222        200.0  False         200.0  44400.0
# A3  300.0          300.0   333        300.0   True         300.0  99900.0
# A4    NaN            NaN  4444          NaN  False           NaN      NaN
#
#    eight
# A1  boat
# A2  boat
# A3  boat
# A4  boat

# %%
len(df.columns)
# Out:
# 8

# %%
df
# Out:
#       one  copy_of_onsex   two  copy_of_one   flag  copy_of_onex    three  \
# A1  100.0          100.0   111        100.0  False         100.0  11100.0
# A2  200.0          200.0   222        200.0  False         200.0  44400.0
# A3  300.0          300.0   333        300.0   True         300.0  99900.0
# A4    NaN            NaN  4444          NaN  False           NaN      NaN
#
#    eight
# A1  boat
# A2  boat
# A3  boat
# A4  boat

# %%
df
# Out:
#       one  copy_of_onsex   two  copy_of_one   flag  copy_of_onex    three  \
# A1  100.0          100.0   111        100.0  False         100.0  11100.0
# A2  200.0          200.0   222        200.0  False         200.0  44400.0
# A3  300.0          300.0   333        300.0   True         300.0  99900.0
# A4    NaN            NaN  4444          NaN  False           NaN      NaN
#
#    eight nine nines  ten
# A1  boat  cat   cat  cat
# A2  boat  cat   cat  cat
# A3  boat  cat   cat  cat
# A4  boat  cat   cat  cat

# %%
df
# Out:
#       one  copy_of_onsex   two  copy_of_one   flag  copy_of_onex    three  \
# A1  100.0          100.0   111        100.0  False         100.0  11100.0
# A2  200.0          200.0   222        200.0  False         200.0  44400.0
# A3  300.0          300.0   333        300.0   True         300.0  99900.0
# A4    NaN            NaN  4444          NaN  False           NaN      NaN
#
#    eight nine nines  ten
# A1  boat  cat   cat  cat
# A2  boat  cat   cat  cat
# A3  boat  cat   cat  cat
# A4  boat  cat   cat  cat

# %% [markdown]
# ## Pandas Data Ingestion

# %%
# !pwd
# Out:
# /Users/Scott/Documents/Python/Week4/Week-4-Pandas

# %%
# !cd ..

# %%
# !ls
# Out:
# Icon?                          Week-4-Practice-Notebook.ipynb
# Introduction to Pandas.ipynb   movielens

# %%
# !pwd
# Out:
# /Users/Scott/Documents/Python/Week4/Week-4-Pandas

# %%
# !cd ./movielens

# %%
# !pwd
# Out:
# /Users/Scott/Documents/Python/Week4/Week-4-Pandas

# %%
# !ls ./movielens
# Out:
# Icon?             genome-scores.csv links.csv         ratings.csv
# README.txt        genome-tags.csv   movies.csv        tags.csv

# %%
# !cat ./movielens/movies.csv | wc -l
# Out:
#    27279

# %%
# !head -5 ./movielens/ratings.csv
# Out:
# userId,movieId,rating,timestamp
# 1,2,3.5,1112486027
# 1,29,3.5,1112484676
# 1,32,3.5,1112484819
# 1,47,3.5,1112484727

# %% [markdown]
# ## use pandas to read the dataset

# %%
movies = pd.read_csv('./movielens/movies.csv', sep=',')
print(type(movies))
movies.head(16)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#     movieId                               title  \
# 0         1                    Toy Story (1995)
# 1         2                      Jumanji (1995)
# 2         3             Grumpier Old Men (1995)
# 3         4            Waiting to Exhale (1995)
# 4         5  Father of the Bride Part II (1995)
# 5         6                         Heat (1995)
# 6         7                      Sabrina (1995)
# 7         8                 Tom and Huck (1995)
# 8         9                 Sudden Death (1995)
# 9        10                    GoldenEye (1995)
# 10       11      American President, The (1995)
# 11       12  Dracula: Dead and Loving It (1995)
# 12       13                        Balto (1995)
# 13       14                        Nixon (1995)
# 14       15             Cutthroat Island (1995)
# 15       16                       Casino (1995)
#
#                                          genres
# 0   Adventure|Animation|Children|Comedy|Fantasy
# ...

# %%
# !ls ./movielens
# Out:
# Icon?             genome-scores.csv links.csv         ratings.csv
# README.txt        genome-tags.csv   movies.csv        tags.csv

# %%
tags = pd.read_csv('./movielens/tags.csv', sep=',')

# %%
print(type(tags))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
tags.head()
# Out:
#    userId  movieId            tag   timestamp
# 0      18     4141    Mark Waters  1240597180
# 1      65      208      dark hero  1368150078
# 2      65      353      dark hero  1368150079
# 3      65      521  noir thriller  1368149983
# 4      65      592      dark hero  1368150078

# %%
ratings = pd.read_csv('./movielens/ratings.csv', sep=',')
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1        2     3.5  1112486027
# 1       1       29     3.5  1112484676
# 2       1       32     3.5  1112484819
# 3       1       47     3.5  1112484727
# 4       1       50     3.5  1112484580

# %%
del ratings['timestamp']
del tags['timestamp']

# %%
ratings.head()
# Out:
#    userId  movieId  rating
# 0       1        2     3.5
# 1       1       29     3.5
# 2       1       32     3.5
# 3       1       47     3.5
# 4       1       50     3.5

# %%
tags.head()
# Out:
#    userId  movieId            tag
# 0      18     4141    Mark Waters
# 1      65      208      dark hero
# 2      65      353      dark hero
# 3      65      521  noir thriller
# 4      65      592      dark hero

# %%
row_0 = tags.iloc[0]

# %%
type(row_0)
# Out:
# pandas.core.series.Series

# %%
print(row_0)
# Out:
# userId              18
# movieId           4141
# tag        Mark Waters
# Name: 0, dtype: object

# %%
row_0.index
# Out:
# Index(['userId', 'movieId', 'tag'], dtype='object')

# %%
row_0['movieId']
# Out:
# 4141

# %%
row_0['userId']
# Out:
# 18

# %%
'rating' in row_0
# Out:
# False

# %%
tags.iloc[[0, 11, 2000]]
# Out:
#       userId  movieId                tag
# 0         18     4141        Mark Waters
# 11        65     1783      noir thriller
# 2000     910    68554  conspiracy theory

# %%
tags.head()
# Out:
#    userId  movieId            tag
# 0      18     4141    Mark Waters
# 1      65      208      dark hero
# 2      65      353      dark hero
# 3      65      521  noir thriller
# 4      65      592      dark hero

# %% [markdown]
# ## Descriptive Statistics

# %%
ratings['rating'].describe()
# Out:
# count    2.000026e+07
# mean     3.525529e+00
# std      1.051989e+00
# min      5.000000e-01
# 25%      3.000000e+00
# 50%      3.500000e+00
# 75%      4.000000e+00
# max      5.000000e+00
# Name: rating, dtype: float64

# %%
ratings['rating'].mean()
# Out:
# 3.5255285642993797

# %%
ratings.describeibe()
# Out:
#              userId       movieId        rating
# count  2.000026e+07  2.000026e+07  2.000026e+07
# mean   6.904587e+04  9.041567e+03  3.525529e+00
# std    4.003863e+04  1.978948e+04  1.051989e+00
# min    1.000000e+00  1.000000e+00  5.000000e-01
# 25%    3.439500e+04  9.020000e+02  3.000000e+00
# 50%    6.914100e+04  2.167000e+03  3.500000e+00
# 75%    1.036370e+05  4.770000e+03  4.000000e+00
# max    1.384930e+05  1.312620e+05  5.000000e+00

# %%
ratings.mean()
# Out:
# userId     69045.872583
# movieId     9041.567330
# rating         3.525529
# dtype: float64

# %%
ratings['rating'].min()
# Out:
# 0.5

# %%
ratings['rating'].max()
# Out:
# 5.0

# %%
ratings['rating'].std()
# Out:
# 1.051988919275684

# %%
ratings['rating'].mode()
# Out:
# 0    4.0
# dtype: float64

# %%
ratings.corr()
# Out:
#            userId   movieId    rating
# userId   1.000000 -0.000850  0.001175
# movieId -0.000850  1.000000  0.002606
# rating   0.001175  0.002606  1.000000

# %%
filter_1 = ratings['rating'] > 5
filter_1.any()
# Out:
# False

# %%
type(filter_1)
# Out:
# pandas.core.series.Series

# %%
print(filter_1)
# Out:
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# 5           False
# 6           False
# 7           False
# 8           False
# 9           False
# 10          False
# 11          False
# 12          False
# 13          False
# 14          False
# 15          False
# 16          False
# 17          False
# 18          False
# 19          False
# 20          False
# 21          False
# 22          False
# 23          False
# 24          False
# 25          False
# 26          False
# 27          False
# 28          False
# 29          False
#             ...
# 20000233    False
# 20000234    False
# 20000235    False
# 20000236    False
# 20000237    False
# 20000238    False
# 20000239    False
# 20000240    False
# 20000241    False
# 20000242    False
# 20000243    False
# 20000244    False
# 20000245    False
# 20000246    False
# 20000247    False
# 20000248    False
# 20000249    False
# 20000250    False
# 20000251    False
# ...

# %%
filter_2 = ratings['rating'] > 0
filter_2.any()
# Out:
# True

# %% [markdown]
# ## Data Cleaning

# %%
movies.shape
# Out:
# (27278, 3)

# %%
#is any row null
movies.isnull().any()
# Out:
# movieId    False
# title      False
# genres     False
# dtype: bool

# %%
tags.isnull().any()
# Out:
# userId     False
# movieId    False
# tag         True
# dtype: bool

# %%
tags = tags.dropna()

# %%
tags.isnull().any()
# Out:
# userId     False
# movieId    False
# tag        False
# dtype: bool

# %%
tags.shape
# Out:
# (465548, 3)

# %% [markdown]
# ## Data Visualizations

# %%
df
# Out:
#       one  copy_of_onsex   two  copy_of_one   flag  copy_of_onex    three  \
# A1  100.0          100.0   111        100.0  False         100.0  11100.0
# A2  200.0          200.0   222        200.0  False         200.0  44400.0
# A3  300.0          300.0   333        300.0   True         300.0  99900.0
# A4    NaN            NaN  4444          NaN  False           NaN      NaN
#
#    eight nine nines  ten
# A1  boat  cat   cat  cat
# A2  boat  cat   cat  cat
# A3  boat  cat   cat  cat
# A4  boat  cat   cat  cat

# %%
# %matplotlib inline

# %%
df.plot.hist()

# %%
df.plot()

# %%
df.plot.box()

# %%
ratings.hist(column='rating', figsize=(15,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11005c5c0>]], dtype=object)

# %%
ratings.boxplot('rating', figsize=(5, 5))

# %% [markdown]
# # Frequent Data Operations

# %%
df
# Out:
#       one  copy_of_onsex   two  copy_of_one   flag  copy_of_onex    three  \
# A1  100.0          100.0   111        100.0  False         100.0  11100.0
# A2  200.0          200.0   222        200.0  False         200.0  44400.0
# A3  300.0          300.0   333        300.0   True         300.0  99900.0
# A4    NaN            NaN  4444          NaN  False           NaN      NaN
#
#    eight nine nines  ten
# A1  boat  cat   cat  cat
# A2  boat  cat   cat  cat
# A3  boat  cat   cat  cat
# A4  boat  cat   cat  cat

# %%
del df['copy_of_onsex']

# %%
df
# Out:
#       one   two  copy_of_one   flag  copy_of_onex    three eight nine nines  \
# A1  100.0   111        100.0  False         100.0  11100.0  boat  cat   cat
# A2  200.0   222        200.0  False         200.0  44400.0  boat  cat   cat
# A3  300.0   333        300.0   True         300.0  99900.0  boat  cat   cat
# A4    NaN  4444          NaN  False           NaN      NaN  boat  cat   cat
#
#     ten
# A1  cat
# A2  cat
# A3  cat
# A4  cat

# %%
del df['copy_of_onex']

# %%
df
# Out:
#       one   two   flag    three eight nine nines  ten
# A1  100.0   111  False  11100.0  boat  cat   cat  cat
# A2  200.0   222  False  44400.0  boat  cat   cat  cat
# A3  300.0   333   True  99900.0  boat  cat   cat  cat
# A4    NaN  4444  False      NaN  boat  cat   cat  cat

# %%
df['eleven'] = df['two']+100

# %%
df
# Out:
#       one   two   flag    three eight nine nines  ten  eleven
# A1  100.0   111  False  11100.0  boat  cat   cat  cat     211
# A2  200.0   222  False  44400.0  boat  cat   cat  cat     322
# A3  300.0   333   True  99900.0  boat  cat   cat  cat     433
# A4    NaN  4444  False      NaN  boat  cat   cat  cat    4544

# %%
del df['nine']

# %%
df
# Out:
#       one   two   flag    three eight nines  ten  eleven
# A1  100.0   111  False  11100.0  boat   cat  cat     211
# A2  200.0   222  False  44400.0  boat   cat  cat     322
# A3  300.0   333   True  99900.0  boat   cat  cat     433
# A4    NaN  4444  False      NaN  boat   cat  cat    4544

# %%
del df['eight'], df['nines']

# %%
df
# Out:
#       one   two   flag    three  ten  eleven
# A1  100.0   111  False  11100.0  cat     211
# A2  200.0   222  False  44400.0  cat     322
# A3  300.0   333   True  99900.0  cat     433
# A4    NaN  4444  False      NaN  cat    4544

# %%
del df['ten']

# %%
df
# Out:
#       one   two   flag    three  eleven
# A1  100.0   111  False  11100.0     211
# A2  200.0   222  False  44400.0     322
# A3  300.0   333   True  99900.0     433
# A4    NaN  4444  False      NaN    4544

# %%
del df['flag']
df
# Out:
#       one   two    three  eleven
# A1  100.0   111  11100.0     211
# A2  200.0   222  44400.0     322
# A3  300.0   333  99900.0     433
# A4    NaN  4444      NaN    4544

# %%
df.index
# Out:
# Index(['A1', 'A2', 'A3', 'A4'], dtype='object')

# %%
df.columns
# Out:
# Index(['one', 'two', 'three', 'eleven'], dtype='object')

# %%
df.columns[3]
# Out:
# 'eleven'

# %%
df = df.rename(columns={'eleven':'four'})

# %%
df
# Out:
#       one   two    three  four
# A1  100.0   111  11100.0   211
# A2  200.0   222  44400.0   322
# A3  300.0   333  99900.0   433
# A4    NaN  4444      NaN  4544

# %%
df.columns = ['one', 'two', 'three', 'five']

# %%
df
# Out:
#       one   two    three  five
# A1  100.0   111  11100.0   211
# A2  200.0   222  44400.0   322
# A3  300.0   333  99900.0   433
# A4    NaN  4444      NaN  4544

# %%
df.columns[3]
# Out:
# 'five'

# %%
df
# Out:
#       one   two    three  five
# A1  100.0   111  11100.0   211
# A2  200.0   222  44400.0   322
# A3  300.0   333  99900.0   433
# A4    NaN  4444      NaN  4544

# %%
df.values
# Out:
# array([[   100.,    111.,  11100.,    211.],
#        [   200.,    222.,  44400.,    322.],
#        [   300.,    333.,  99900.,    433.],
#        [    nan,   4444.,     nan,   4544.]])

# %%
df
# Out:
#       one   two    three  five
# A1  100.0   111  11100.0   211
# A2  200.0   222  44400.0   322
# A3  300.0   333  99900.0   433
# A4    NaN  4444      NaN  4544

# %%
df.loc

# %%
len(df)
# Out:
# 4

# %%
df.loc[len(df)] = [11,22,33,44]
df
# Out:
#       one   two    three  five
# A1  100.0   111  11100.0   211
# A2  200.0   222  44400.0   322
# A3  300.0   333  99900.0   433
# A4    NaN  4444      NaN  4544
# 4    11.0    22     33.0    44
# 5    11.0    22     33.0    44

# %%
# Out:
#       one   two    three  five
# A1  100.0   111  11100.0   211
# A2  200.0   222  44400.0   322
# A3  300.0   333  99900.0   433
# A4    NaN  4444      NaN  4544
# 4    11.0    22     33.0    44
# 5    11.0    22     33.0    44

# %%
df.drop(df.index[[5]])
# Out:
#       one   two    three  five
# A1  100.0   111  11100.0   211
# A2  200.0   222  44400.0   322
# A3  300.0   333  99900.0   433
# A4    NaN  4444      NaN  4544
# 4    11.0    22     33.0    44

# %%
df.groupby('one').mean()
# Out:
#        two    three  five
# one
# 11.0    22     33.0    44
# 100.0  111  11100.0   211
# 200.0  222  44400.0   322
# 300.0  333  99900.0   433

# %% [markdown]
# ## Frequent data operations

# %%
#slicing columns
tags['tag'].head()
# Out:
# 0      Mark Waters
# 1        dark hero
# 2        dark hero
# 3    noir thriller
# 4        dark hero
# Name: tag, dtype: object

# %%
movies[['title', 'genres']].head()
# Out:
#                                 title  \
# 0                    Toy Story (1995)
# 1                      Jumanji (1995)
# 2             Grumpier Old Men (1995)
# 3            Waiting to Exhale (1995)
# 4  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
ratings[1000:1010] #select specific range of rows
# Out:
#       userId  movieId  rating
# 1000      11      527     4.5
# 1001      11      531     4.5
# 1002      11      541     4.5
# 1003      11      546     5.0
# 1004      11      551     5.0
# 1005      11      586     4.0
# 1006      11      587     4.5
# 1007      11      588     5.0
# 1008      11      589     4.5
# 1009      11      592     4.5

# %%
ratings[:10] #first ten rows
# Out:
#    userId  movieId  rating
# 0       1        2     3.5
# 1       1       29     3.5
# 2       1       32     3.5
# 3       1       47     3.5
# 4       1       50     3.5
# 5       1      112     3.5
# 6       1      151     4.0
# 7       1      223     4.0
# 8       1      253     4.0
# 9       1      260     4.0

# %%
ratings[-10:] # ten rows from the bottom
# Out:
#           userId  movieId  rating
# 20000253  138493    60816     4.5
# 20000254  138493    61160     4.0
# 20000255  138493    65682     4.5
# 20000256  138493    66762     4.5
# 20000257  138493    68319     4.5
# 20000258  138493    68954     4.5
# 20000259  138493    69526     4.5
# 20000260  138493    69644     3.0
# 20000261  138493    70286     5.0
# 20000262  138493    71619     2.5

# %%
#value counts
tag_counts = tags['tag'].value_counts()
tag_counts[:10]
# Out:
# sci-fi             3384
# based on a book    3281
# atmospheric        2917
# comedy             2779
# action             2657
# surreal            2427
# BD-R               2334
# twist ending       2323
# funny              2072
# dystopia           1991
# Name: tag, dtype: int64

# %%
tag_counts[:10].plot(kind='bar', figsize=(10,4), color='green', fontsize=15)

# %%
## filtering out rows ##
is_highly_rated = ratings['rating'] >= 4

# %%
ratings[is_highly_rated][-5:]
# Out:
#           userId  movieId  rating
# 20000256  138493    66762     4.5
# 20000257  138493    68319     4.5
# 20000258  138493    68954     4.5
# 20000259  138493    69526     4.5
# 20000261  138493    70286     5.0

# %%
movies['genres'][:10]
# Out:
# 0    Adventure|Animation|Children|Comedy|Fantasy
# 1                     Adventure|Children|Fantasy
# 2                                 Comedy|Romance
# 3                           Comedy|Drama|Romance
# 4                                         Comedy
# 5                          Action|Crime|Thriller
# 6                                 Comedy|Romance
# 7                             Adventure|Children
# 8                                         Action
# 9                      Action|Adventure|Thriller
# Name: genres, dtype: object

# %%
is_animation = movies['genres'].str.contains('Animation') ## filter to find animation genre using string contains

# %%
movies[is_animation][:10] ## is animation is a filter, return the first ten rows of animation genres
# Out:
#      movieId                                       title  \
# 0          1                            Toy Story (1995)
# 12        13                                Balto (1995)
# 47        48                           Pocahontas (1995)
# 236      239                       Goofy Movie, A (1995)
# 241      244                     Gumby: The Movie (1995)
# 310      313                   Swan Princess, The (1994)
# 360      364                       Lion King, The (1994)
# 388      392  Secret Adventures of Tom Thumb, The (1993)
# 547      551      Nightmare Before Christmas, The (1993)
# 553      558                      Pagemaster, The (1994)
#
#                                               genres
# 0        Adventure|Animation|Children|Comedy|Fantasy
# 12                      Adventure|Animation|Children
# 47          Animation|Children|Drama|Musical|Romance
# 236                Animation|Children|Comedy|Romance
# 241                               Animation|Children
# ...

# %%
## group by and aggregation
average_rating = ratings[['movieId', 'rating']].groupby('movieId').mean()

# %%
average_rating.tail(10)
# Out:
#          rating
# movieId
# 131241      4.0
# 131243      4.0
# 131248      4.0
# 131250      4.0
# 131252      4.0
# 131254      4.0
# 131256      4.0
# 131258      2.5
# 131260      3.0
# 131262      4.0

# %%
average_rating[:10]
# Out:
#            rating
# movieId
# 1        3.921240
# 2        3.211977
# 3        3.151040
# 4        2.861393
# 5        3.064592
# 6        3.834930
# 7        3.366484
# 8        3.142049
# 9        3.004924
# 10       3.430029

# %%
## group by and aggregation
ratings_count = ratings[['movieId', 'rating']].groupby('movieId').count()

# %%
ratings_count[:10]
# Out:
#          rating
# movieId
# 1         49695
# 2         22243
# 3         12735
# 4          2756
# 5         12161
# 6         23899
# 7         12961
# 8          1415
# 9          3960
# 10        29005

# %%
# !pwd
# Out:
# /Users/Scott/Documents/Python/Week4/Week-4-Pandas

# %%
# !head -5 /Users/Scott/OneDrive/oderHIstory122017.csv
# Out:
# ﻿CommerceTransactionDetailId,LineNumber,QuantityOrdered,QuantityShipped,CallForPrice,ItemListPrice,PriceExtension,Sku,ItemDescription,PublicationId,UnitOfMeasure,ActionTime,Agent,ERPCode,WebTransactionNumber,ERPTransactionNumber
# 9417366,1,2,2,0,224.10000,448.20000,9621125,TUBING MFLEX STA-PURE #25 12",FF,PK,2017-12-20 19:04:35.960,OMS,CPI,,8384249-00
# 9453094,1,2,0,0,667.20000,1334.40000,7771384,PUMP MFLEX L/S ECON TK 115V,VA,EA,2017-12-20 19:04:35.960,OMS,CPI,,8397506-00
# 9453095,2,2,2,0,1483.20000,2966.40000,7771252,PUMP MFLEX L/S 600RPM ELIITHK,VA,EA,2017-12-20 19:04:35.960,OMS,CPI,,8397506-00
# 9453096,3,4,4,0,2263.20000,9052.80000,7771418,PUMP MFLX I/P BRUSHLESS I/O EL,VA,EA,2017-12-20 19:04:35.960,OMS,CPI,,8397506-00

# %%
orders = pd.read_csv('/Users/Scott/OneDrive/oderHIstory122017.csv', sep=',')

# %%
orders.head()
# Out:
#    CommerceTransactionDetailId  LineNumber  QuantityOrdered  QuantityShipped  \
# 0                      9417366           1                2                2
# 1                      9453094           1                2                0
# 2                      9453095           2                2                2
# 3                      9453096           3                4                4
# 4                      9453097           4                1                0
#
#    CallForPrice  ItemListPrice  PriceExtension      Sku  \
# 0             0          224.1           448.2  9621125
# 1             0          667.2          1334.4  7771384
# 2             0         1483.2          2966.4  7771252
# 3             0         2263.2          9052.8  7771418
# 4             0          667.2           667.2  7771380
#
#                   ItemDescription PublicationId UnitOfMeasure  \
# 0   TUBING MFLEX STA-PURE #25 12"            FF            PK
# ...

# %%
print(type(orders))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
orders['ItemListPrice'].describe()
# Out:
# count    562429.000000
# mean        294.304907
# std        1104.796086
# min           0.000000
# 25%          23.960000
# 50%          64.800000
# 75%         175.000000
# max       99000.000000
# Name: ItemListPrice, dtype: float64

# %%
orders['PriceExtension'].describe()
# Out:
# count    5.624290e+05
# mean     6.480944e+02
# std      6.553293e+03
# min      0.000000e+00
# 25%      4.107000e+01
# 50%      1.244000e+02
# 75%      3.670000e+02
# max      2.544000e+06
# Name: PriceExtension, dtype: float64

# %%
orders_count = orders[['ERPTransactionNumber', 'Sku']].groupby('ERPTransactionNumber').count().sort_values(['Sku'], ascending=False)

# %%
orders.index
# Out:
# RangeIndex(start=0, stop=562429, step=1)

# %%
orders.head()
# Out:
#    CommerceTransactionDetailId  LineNumber  QuantityOrdered  QuantityShipped  \
# 0                      9417366           1                2                2
# 1                      9453094           1                2                0
# 2                      9453095           2                2                2
# 3                      9453096           3                4                4
# 4                      9453097           4                1                0
#
#    CallForPrice  ItemListPrice  PriceExtension      Sku  \
# 0             0          224.1           448.2  9621125
# 1             0          667.2          1334.4  7771384
# 2             0         1483.2          2966.4  7771252
# 3             0         2263.2          9052.8  7771418
# 4             0          667.2           667.2  7771380
#
#                   ItemDescription PublicationId UnitOfMeasure  \
# 0   TUBING MFLEX STA-PURE #25 12"            FF            PK
# ...

# %%
orders[['Sku', 'QuantityOrdered']][:100].sort_values(['QuantityOrdered'], ascending=False)
# Out:
#         Sku  QuantityOrdered
# 24  2951050               12
# 61  3605020                8
# 35  8651501                6
# 40  0642416                5
# 48  2857343                4
# 62  9876301                4
# 3   7771418                4
# 42  2857361                4
# 47  2857363                4
# 90  0620920                4
# 25  6897506                4
# 26  1704012                4
# 50  2857308                3
# 46  2857311                3
# 49  2857338                3
# 44  2857341                3
# 43  2857336                3
# 41  2857000                3
# 45  2857306                3
# 53  2857259                3
# 51  2857313                3
# 55  2857265                3
# 95  2002701                3
# 1   7771384                2
# 52  2857258                2
# 54  2857264                2
# 60  0641711                2
# 72  9121045                2
# 73  9876833                2
# 84  9999962                2
# ..      ...              ...
# ...

# %%
orders[orders['QuantityOrdered'] > 5]
# Out:
#         CommerceTransactionDetailId  LineNumber  QuantityOrdered  \
# 24                          9463798           1               12
# 35                          9466105           1                6
# 61                          9467831           1                8
# 111                         9468689           1               10
# 112                         9468690           2               25
# 166                         9469081           1               10
# 189                         9469365           1                6
# 190                         9469414           1               30
# 192                         9469417           1               10
# 215                         9469586           1               12
# 216                         9469606           1               10
# 226                         9470094           1               20
# 239                         9470147           1               12
# ...

# %%
orders[['ERPTransactionNumber', 'Sku']].groupby('Sku', as_index=False).count()[:130]
# Out:
#          Sku  ERPTransactionNumber
# 0    00001DI                     3
# 1    00001EI                     3
# 2    00001EN                     2
# 3    00001EW                     2
# 4    00001FP                     1
# 5    00001FR                     2
# 6    00001GP                     1
# 7    00001HF                     1
# 8    00001JF                     1
# 9    00001OL                     1
# 10   00001OW                     1
# 11   00001RV                     2
# 12   00001XF                     2
# 13   00001YA                     5
# 14   00002BQ                     1
# 15   00002CY                     2
# 16   00002CZ                     2
# 17   00002EP                     3
# 18   00002NA                     8
# 19   00002NW                     1
# 20   00002PP                     1
# 21   00002PQ                     1
# 22   00002QF                     4
# 23   00003FO                     1
# 24   00003FP                     6
# 25   00003FT                     2
# ...

# %%
tags.head()
# Out:
#    userId  movieId            tag
# 0      18     4141    Mark Waters
# 1      65      208      dark hero
# 2      65      353      dark hero
# 3      65      521  noir thriller
# 4      65      592      dark hero

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
t = pd.merge(tags, movies, how = 'inner') ## couple different ways to do a merge ##
t.head(5)
# Out:
#    userId  movieId                 tag                   title  \
# 0      18     4141         Mark Waters  Head Over Heels (2001)
# 1   66193     4141               naive  Head Over Heels (2001)
# 2   70201     4141         Mark Waters  Head Over Heels (2001)
# 3   89274     4141  Freddie Prinze Jr.  Head Over Heels (2001)
# 4      65      208           dark hero       Waterworld (1995)
#
#                     genres
# 0           Comedy|Romance
# 1           Comedy|Romance
# 2           Comedy|Romance
# 3           Comedy|Romance
# 4  Action|Adventure|Sci-Fi

# %%
t2 = tags.merge(movies, on = 'movieId', how='inner') ## couple ways to do a merge ##
t2.head()
# Out:
#    userId  movieId                 tag                   title  \
# 0      18     4141         Mark Waters  Head Over Heels (2001)
# 1   66193     4141               naive  Head Over Heels (2001)
# 2   70201     4141         Mark Waters  Head Over Heels (2001)
# 3   89274     4141  Freddie Prinze Jr.  Head Over Heels (2001)
# 4      65      208           dark hero       Waterworld (1995)
#
#                     genres
# 0           Comedy|Romance
# 1           Comedy|Romance
# 2           Comedy|Romance
# 3           Comedy|Romance
# 4  Action|Adventure|Sci-Fi

# %%
avg_ratings = ratings.groupby('movieId', as_index=False).mean()
avg_ratings.head()
# Out:
#    movieId        userId    rating
# 0        1  69282.396821  3.921240
# 1        2  69169.928202  3.211977
# 2        3  69072.079388  3.151040
# 3        4  69652.913280  2.861393
# 4        5  69113.475454  3.064592

# %%
del avg_ratings['userId']

# %%
avg_ratings.head()
# Out:
#    movieId    rating
# 0        1  3.921240
# 1        2  3.211977
# 2        3  3.151040
# 3        4  2.861393
# 4        5  3.064592

# %%
box_office = movies.merge(avg_ratings, on= 'movieId', how='inner')
box_office.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres    rating
# 0  Adventure|Animation|Children|Comedy|Fantasy  3.921240
# 1                   Adventure|Children|Fantasy  3.211977
# 2                               Comedy|Romance  3.151040
# 3                         Comedy|Drama|Romance  2.861393
# 4                                       Comedy  3.064592

# %%
is_highly_rated = box_office['rating'] >=4
box_office[is_highly_rated][:5]
# Out:
#      movieId                            title                  genres  \
# 27        28                Persuasion (1995)           Drama|Romance
# 46        47      Seven (a.k.a. Se7en) (1995)        Mystery|Thriller
# 49        50       Usual Suspects, The (1995)  Crime|Mystery|Thriller
# 81        82  Antonia's Line (Antonia) (1995)            Comedy|Drama
# 108      110                Braveheart (1995)        Action|Drama|War
#
#        rating
# 27   4.057546
# 46   4.053493
# 49   4.334372
# 81   4.004925
# 108  4.042534

# %%
is_comedy = box_office['genres'].str.contains('Comedy')
box_office[is_comedy][:10]
# Out:
#     movieId                                  title  \
# 0         1                       Toy Story (1995)
# 2         3                Grumpier Old Men (1995)
# 3         4               Waiting to Exhale (1995)
# 4         5     Father of the Bride Part II (1995)
# 6         7                         Sabrina (1995)
# 10       11         American President, The (1995)
# 11       12     Dracula: Dead and Loving It (1995)
# 17       18                      Four Rooms (1995)
# 18       19  Ace Ventura: When Nature Calls (1995)
# 19       20                     Money Train (1995)
#
#                                          genres    rating
# 0   Adventure|Animation|Children|Comedy|Fantasy  3.921240
# 2                                Comedy|Romance  3.151040
# 3                          Comedy|Drama|Romance  2.861393
# 4                                        Comedy  3.064592
# 6                                Comedy|Romance  3.366484
# ...

# %%
box_office[is_comedy & is_highly_rated][:10]
# Out:
#      movieId                                              title  \
# 81        82                    Antonia's Line (Antonia) (1995)
# 229      232        Eat Drink Man Woman (Yin shi nan nu) (1994)
# 293      296                                Pulp Fiction (1994)
# 352      356                                Forrest Gump (1994)
# 602      608                                       Fargo (1996)
# 708      720  Wallace & Gromit: The Best of Aardman Animatio...
# 732      745             Wallace & Gromit: A Close Shave (1995)
# 737      750  Dr. Strangelove or: How I Learned to Stop Worr...
# 765      778                               Trainspotting (1996)
# 881      898                     Philadelphia Story, The (1940)
#
#                           genres    rating
# 81                  Comedy|Drama  4.004925
# 229         Comedy|Drama|Romance  4.035610
# 293  Comedy|Crime|Drama|Thriller  4.174231
# 352     Comedy|Drama|Romance|War  4.029000
# ...

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
movies['year'] = movies['title'].str.extract('.*\((.*)\).*', expand=True)

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres  year
# 0  Adventure|Animation|Children|Comedy|Fantasy  1995
# 1                   Adventure|Children|Fantasy  1995
# 2                               Comedy|Romance  1995
# 3                         Comedy|Drama|Romance  1995
# 4                                       Comedy  1995

# %%
orders.head()
# Out:
#    CommerceTransactionDetailId  LineNumber  QuantityOrdered  QuantityShipped  \
# 0                      9417366           1                2                2
# 1                      9453094           1                2                0
# 2                      9453095           2                2                2
# 3                      9453096           3                4                4
# 4                      9453097           4                1                0
#
#    CallForPrice  ItemListPrice  PriceExtension      Sku  \
# 0             0          224.1           448.2  9621125
# 1             0          667.2          1334.4  7771384
# 2             0         1483.2          2966.4  7771252
# 3             0         2263.2          9052.8  7771418
# 4             0          667.2           667.2  7771380
#
#                   ItemDescription PublicationId UnitOfMeasure  \
# 0   TUBING MFLEX STA-PURE #25 12"            FF            PK
# ...

# %%
## is tubing filter
is_tubing = orders['ItemDescription'].str.contains('tubing')
orders[is_tubing].head()
# Out:
#         CommerceTransactionDetailId  LineNumber  QuantityOrdered  \
# 114466                      9407483           3                1
# 175040                      9364083           1                1
# 180291                      9352617           1                1
# 180292                      9352618           2                1
# 227348                      9314963           1                1
#
#         QuantityShipped  CallForPrice  ItemListPrice  PriceExtension      Sku  \
# 114466                0             0          108.0             0.0  0642436
# 175040                0             0           86.0             0.0  9641025
# 180291                0             0           65.0             0.0  9641013
# 180292                0             0           82.5             0.0  9641014
# 227348                0             0          163.0             0.0  9580932
#
#                                           ItemDescription PublicationId  \
# ...

# %%
test = [1, 20, 30]
test
# Out:
# [1, 20, 30]

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres  year
# 0  Adventure|Animation|Children|Comedy|Fantasy  1995
# 1                   Adventure|Children|Fantasy  1995
# 2                               Comedy|Romance  1995
# 3                         Comedy|Drama|Romance  1995
# 4                                       Comedy  1995

# %%
movies_genres = movies['genres'].str.split('|', expand=True) # separate or split based on the pipe, and expand cols
movies_genres.head()
# Out:
#            0          1         2       3        4     5     6     7     8  \
# 0  Adventure  Animation  Children  Comedy  Fantasy  None  None  None  None
# 1  Adventure   Children   Fantasy    None     None  None  None  None  None
# 2     Comedy    Romance      None    None     None  None  None  None  None
# 3     Comedy      Drama   Romance    None     None  None  None  None  None
# 4     Comedy       None      None    None     None  None  None  None  None
#
#       9
# 0  None
# 1  None
# 2  None
# 3  None
# 4  None

# %%
movies_genres['is_comedy'] = movies['genres'].str.contains('Comedy')

# %%
movies_genres.head()
# Out:
#            0          1         2       3        4     5     6     7     8  \
# 0  Adventure  Animation  Children  Comedy  Fantasy  None  None  None  None
# 1  Adventure   Children   Fantasy    None     None  None  None  None  None
# 2     Comedy    Romance      None    None     None  None  None  None  None
# 3     Comedy      Drama   Romance    None     None  None  None  None  None
# 4     Comedy       None      None    None     None  None  None  None  None
#
#       9  is_comedy
# 0  None       True
# 1  None      False
# 2  None       True
# 3  None       True
# 4  None       True

# %%
comedy = movies['genres'].str.contains('Comedy')
movies_genres[comedy].head()
# Out:
#            0          1         2       3        4     5     6     7     8  \
# 0  Adventure  Animation  Children  Comedy  Fantasy  None  None  None  None
# 2     Comedy    Romance      None    None     None  None  None  None  None
# 3     Comedy      Drama   Romance    None     None  None  None  None  None
# 4     Comedy       None      None    None     None  None  None  None  None
# 6     Comedy    Romance      None    None     None  None  None  None  None
#
#       9  is_comedy
# 0  None       True
# 2  None       True
# 3  None       True
# 4  None       True
# 6  None       True
